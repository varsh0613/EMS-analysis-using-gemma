# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\SAHARA\Downloads\Emergency_Medical_Service_(EMS)_Incidents_20251121.csv")
 # your file name
df.head()
# Out:
# C:\Users\SAHARA\AppData\Local\Temp\ipykernel_3616\1317772999.py:3: DtypeWarning: Columns (9,12,16,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\SAHARA\Downloads\Emergency_Medical_Service_(EMS)_Incidents_20251121.csv")
#   Incident Number  Time Call Was Received Time Vehicle was Dispatched  \
# 0       F20034505  12/24/2020 05:00:00 AM     2020 Dec 24 05:00:00 AM
# 1       F20034541  12/24/2020 02:07:00 PM     2020 Dec 24 02:07:00 PM
# 2       F20034713  12/26/2020 01:40:00 PM     2020 Dec 26 01:40:00 PM
# 3        NC114316  12/16/2020 01:07:00 PM                         NaN
# 4       F20035145  12/31/2020 10:28:00 AM     2020 Dec 31 10:28:00 AM
#
#   Time Vehicle was en Route to Scene    Time Arrived on Scene  \
# 0            2020 Dec 24 05:03:00 AM  2020 Dec 24 05:09:00 AM
# 1            2020 Dec 24 02:08:00 PM  2020 Dec 24 02:11:00 PM
# 2            2020 Dec 26 01:42:00 PM                      NaN
# ...

# %%
df = df.drop_duplicates(subset="Incident_Number", keep="first")

print(f"Rows after dropping duplicates: {len(df)}")
# Out:
# Rows after dropping duplicates: 109156

# %%
OUTPUT_PATH = r"C:\Users\SAHARA\OneDrive\Desktop\uni\gemma\cleaning\cleaned_ems_data.csv"
df.to_csv(OUTPUT_PATH, index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149978 entries, 0 to 149977
# Data columns (total 29 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   Incident Number                                    149973 non-null  object
#  1   Time Call Was Received                             149976 non-null  object
#  2   Time Vehicle was Dispatched                        148311 non-null  object
#  3   Time Vehicle was en Route to Scene                 149944 non-null  object
#  4   Time Arrived on Scene                              144353 non-null  object
#  5   Time Arrived at Patient                            137972 non-null  object
#  6   Time Departed from the Scene                       124145 non-null  object
#  7   Time Arrived to Next Destination (i.e., Hospital)  117726 non-null  object
# ...

# %%
hos=df['Where_Patient_was_Transported'].value_counts().rename_axis('Where_Patient_was_Transported').reset_index(name='Count')
print(hos)
# Out:
#               Where_Patient_was_Transported  Count
# 0                    Marin General Hospital  53473
# 1                        Kaiser Terra Linda  17350
# 2                 Novato Community Hospital  15286
# 3                                   Unknown  11886
# 4             Kaiser Permanente, San Rafael   9627
# ..                                      ...    ...
# 56                                      CHP      1
# 57               Summit Alta Bates Berkeley      1
# 58                          Inverness Store      1
# 59           Mills Peninsula Medical Center      1
# 60  Alameda County Medical Center, Highland      1
#
# [61 rows x 2 columns]

# %%
df_sample= df.sample(n=100, random_state=42)
df_sample.to_csv("sampled_data.csv", index=False)

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\SAHARA\AppData\Local\Programs\Python\Python313\python.exe

# %%
df.columns
# Out:
# Index(['Incident Number', 'Time Call Was Received',
#        'Time Vehicle was Dispatched', 'Time Vehicle was en Route to Scene',
#        'Time Arrived on Scene', 'Time Arrived at Patient',
#        'Time Departed from the Scene',
#        'Time Arrived to Next Destination (i.e., Hospital)',
#        'Year Call Received', 'Month Call Received', 'Incident Address',
#        'Incident City', 'Incident ZIP Postal', 'Incident County',
#        'Primary Impression', 'Primary Injury', 'Injury Detail', 'Injury Place',
#        'Injury Date', 'Protocol Used by EMS Personnel', 'Patient Age',
#        'Patient Home County', 'Patient Gender', 'Disposition',
#        'Where Patient was Transported', 'Incident Geocode Location',
#        'Incident Latitude', 'Incident Longitude', 'Unique ID'],
#       dtype='object')

# %%
from ollama import Client
client = Client()

# %%
df= df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12472 entries, 7619 to 89501
# Data columns (total 29 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Incident Number                                    12472 non-null  object
#  1   Time Call Was Received                             12472 non-null  object
#  2   Time Vehicle was Dispatched                        12472 non-null  object
#  3   Time Vehicle was en Route to Scene                 12472 non-null  object
#  4   Time Arrived on Scene                              12472 non-null  object
#  5   Time Arrived at Patient                            12472 non-null  object
#  6   Time Departed from the Scene                       12472 non-null  object
#  7   Time Arrived to Next Destination (i.e., Hospital)  12472 non-null  object
# ...
